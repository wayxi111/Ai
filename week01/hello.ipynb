# %% [markdown]
# 测试用

# %%
import numpy as np
import matplotlib.pyplot as plt

print("numpy version:", np.__version__)

x = np.linspace(0, 2 * np.pi, 100)
plt.plot(x, np.sin(x))
plt.title("Hello, AI")
plt.show()
# Out:
# numpy version: 2.2.6
